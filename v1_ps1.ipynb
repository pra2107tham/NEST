# %%
import pandas as pd
import openpyxl

# %%
df1 = pd.read_csv('usecase_1_.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   NCT Number  \
# 0             0           1  NCT03302091
# 1             1           2  NCT01948791
# 2             2           5  NCT04621591
# 3             3           6  NCT03130491
# 4             4           8  NCT01580891
#
#                                          Study Title  \
# 0  A Study in People With Normal Kidney Function ...
# 1  16w Interventional Study on Titration and Dose...
# 2           Case Series With Saneso 360° Gastroscope
# 3  European Study Evaluating the EMBLOK Embolic P...
# 4  Evaluate the Clinical Equivalence of Two Nafti...
#
#                                       Study URL   Acronym Study Status  \
# 0  https://clinicaltrials.gov/study/NCT03302091       NaN    COMPLETED
# 1  https://clinicaltrials.gov/study/NCT01948791  INSTINCT    COMPLETED
# 2  https://clinicaltrials.gov/study/NCT04621591       NaN    COMPLETED
# 3  https://clinicaltrials.gov/study/NCT03130491       NaN    COMPLETED
# 4  https://clinicaltrials.gov/study/NCT01580891       NaN    COMPLETED
#
#                                        Brief Summary Study Results  \
# 0  The primary objective of the current study is ...           YES
# 1  To investigate the efficacy of Exelon capsule ...           YES
# 2  To confirm the procedural performance of the S...            NO
# 3  The primary objective is to evaluate the perfo...            NO
# 4  The objective of this study is to evaluate the...            NO
#
#                     Conditions  ...  \
# 0  Renal Insufficiency|Healthy  ...
# 1          Alzheimer's Disease  ...
# 2                EGD Procedure  ...
# 3         Aortic Valve Disease  ...
# 4                  Tinea Pedis  ...
#
#                                         Study Design  \
# 0  Allocation: NON_RANDOMIZED|Intervention Model:...
# 1  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2  Allocation: NA|Intervention Model: SINGLE_GROU...
# 3  Allocation: NA|Intervention Model: SINGLE_GROU...
# 4  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#                   Other IDs  Start Date Primary Completion Date  \
# 0  1386-0002|2017-002180-18  2017-10-17              2018-08-16
# 1              CENA713BCN05     2014-08                 2015-09
# 2               SAN360UGICL  2020-08-01              2020-08-30
# 3               CLP002-2016  2017-03-08              2021-11-01
# 4               NTFC 1105.0     2012-05                 2013-03
#
#   Completion Date First Posted Results First Posted Last Update Posted  \
# 0      2018-08-16   2017-10-04           2021-06-04         2021-06-04
# 1         2015-09   2013-09-24           2017-02-13         2017-02-13
# 2      2020-09-09   2020-11-09                  NaN         2020-11-10
# 3      2022-01-28   2017-04-26                  NaN         2024-03-05
# 4         2013-07   2012-04-19                  NaN         2014-05-06
#
#                                            Locations  \
# 0  CRS Clinical Research Services Kiel GmbH, Kiel...
# 1  Novartis Investigative Site, Beijing, 100053, ...
# 2  Valley Endoscopy Center, Saint Clairsville, Oh...
# 3  Hospital San Donato, Milan, Milano, 20097, Ita...
# 4                                                NaN
#
#                                      Study Documents
# 0  Study Protocol, https://cdn.clinicaltrials.gov...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 32 columns]

# %%
df1.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)

# %%
df1.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT03302091  A Study in People With Normal Kidney Function ...
# 1  NCT01948791  16w Interventional Study on Titration and Dose...
# 2  NCT04621591           Case Series With Saneso 360° Gastroscope
# 3  NCT03130491  European Study Evaluating the EMBLOK Embolic P...
# 4  NCT01580891  Evaluate the Clinical Equivalence of Two Nafti...
#
#                                       Study URL   Acronym Study Status  \
# 0  https://clinicaltrials.gov/study/NCT03302091       NaN    COMPLETED
# 1  https://clinicaltrials.gov/study/NCT01948791  INSTINCT    COMPLETED
# 2  https://clinicaltrials.gov/study/NCT04621591       NaN    COMPLETED
# 3  https://clinicaltrials.gov/study/NCT03130491       NaN    COMPLETED
# 4  https://clinicaltrials.gov/study/NCT01580891       NaN    COMPLETED
#
#                                        Brief Summary Study Results  \
# 0  The primary objective of the current study is ...           YES
# 1  To investigate the efficacy of Exelon capsule ...           YES
# 2  To confirm the procedural performance of the S...            NO
# 3  The primary objective is to evaluate the perfo...            NO
# 4  The objective of this study is to evaluate the...            NO
#
#                     Conditions  \
# 0  Renal Insufficiency|Healthy
# 1          Alzheimer's Disease
# 2                EGD Procedure
# 3         Aortic Valve Disease
# 4                  Tinea Pedis
#
#                                        Interventions  \
# 0                                   DRUG: BI 1467335
# 1                                       DRUG: ENA713
# 2                    DEVICE: Saneso 360° gastroscope
# 3  PROCEDURE: Transcatheter Aortic Valve Replacem...
# 4  DRUG: Naftifine HCl Cream 1%|DRUG: Naftin® (Na...
#
#                             Primary Outcome Measures  ...  \
# 0  Area Under the Concentration-time Curve of BI ...  ...
# 1  Mean Change From Baseline in the Alzheimer's D...  ...
# 2  Successful EGD, Procedure success is assessed ...  ...
# 3  Performance Endpoint, successful insertion, pl...  ...
# 4  Therapeutic Cure, Patients with both mycologic...  ...
#
#                                         Study Design  \
# 0  Allocation: NON_RANDOMIZED|Intervention Model:...
# 1  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2  Allocation: NA|Intervention Model: SINGLE_GROU...
# 3  Allocation: NA|Intervention Model: SINGLE_GROU...
# 4  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#                   Other IDs  Start Date Primary Completion Date  \
# 0  1386-0002|2017-002180-18  2017-10-17              2018-08-16
# 1              CENA713BCN05     2014-08                 2015-09
# 2               SAN360UGICL  2020-08-01              2020-08-30
# 3               CLP002-2016  2017-03-08              2021-11-01
# 4               NTFC 1105.0     2012-05                 2013-03
#
#   Completion Date First Posted Results First Posted  Last Update Posted  \
# 0      2018-08-16   2017-10-04           2021-06-04          2021-06-04
# 1         2015-09   2013-09-24           2017-02-13          2017-02-13
# 2      2020-09-09   2020-11-09                  NaN          2020-11-10
# 3      2022-01-28   2017-04-26                  NaN          2024-03-05
# 4         2013-07   2012-04-19                  NaN          2014-05-06
#
#                                            Locations  \
# 0  CRS Clinical Research Services Kiel GmbH, Kiel...
# 1  Novartis Investigative Site, Beijing, 100053, ...
# 2  Valley Endoscopy Center, Saint Clairsville, Oh...
# 3  Hospital San Donato, Milan, Milano, 20097, Ita...
# 4                                                NaN
#
#                                      Study Documents
# 0  Study Protocol, https://cdn.clinicaltrials.gov...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 30 columns]

# %%
metadata = pd.read_excel('Hackathon Metadata.xlsx')

# %%
cols = metadata['Columns']

# %%
cols = cols[:30]
cols
# Out:
# 0                    NCT number
# 1                   Study Title
# 2                     Study URL
# 3                       Acronym
# 4                  Study status
# 5                 Brief summary
# 6                 Study results
# 7            Conditions/disease
# 8       Interventions/treatment
# 9       Primary outcome measure
# 10    Secondary outcome measure
# 11        Other outcome measure
# 12                      Sponsor
# 13                 Collaborator
# 14                          Sex
# 15             Age or age group
# 16                        Phase
# 17                   Enrollment
# 18                  Funder type
# 19                   Study type
# 20                 Study design
# 21                    Other IDs
# 22                   Start date
# 23      Primary completion date
# 24              Completion date
# 25                 First posted
# 26         Results first posted
# 27           Last update posted
# 28                     Location
# 29              Study documents
# Name: Columns, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117980 entries, 0 to 117979
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   NCT Number                  117980 non-null  object
#  1   Study Title                 117980 non-null  object
#  2   Study URL                   117980 non-null  object
#  3   Acronym                     24116 non-null   object
#  4   Study Status                117980 non-null  object
#  5   Brief Summary               117980 non-null  object
#  6   Study Results               117980 non-null  object
#  7   Conditions                  117950 non-null  object
#  8   Interventions               112324 non-null  object
#  9   Primary Outcome Measures    114903 non-null  object
#  10  Secondary Outcome Measures  93200 non-null   object
#  11  Other Outcome Measures      7924 non-null    object
#  12  Sponsor                     117980 non-null  object
#  13  Collaborators               21366 non-null   object
#  14  Sex                         117838 non-null  object
#  15  Age                         117980 non-null  object
#  16  Phases                      83095 non-null   object
#  17  Enrollment                  116147 non-null  float64
#  18  Funder Type                 117980 non-null  object
#  19  Study Type                  117980 non-null  object
#  20  Study Design                117328 non-null  object
#  21  Other IDs                   117977 non-null  object
#  22  Start Date                  116241 non-null  object
#  23  Primary Completion Date     111986 non-null  object
#  24  Completion Date             112654 non-null  object
#  25  First Posted                117980 non-null  object
#  26  Results First Posted        32055 non-null   object
#  27  Last Update Posted          117980 non-null  object
#  28  Locations                   105092 non-null  object
#  29  Study Documents             12858 non-null   object
# dtypes: float64(1), object(29)
# memory usage: 27.0+ MB

# %%
eligibility = pd.read_csv('eligibilities.txt', delimiter='|')

# %%
eligibility.shape
# Out:
# (502301, 14)

# %%
eligibility_test = eligibility.head(500)
eligibility_test.to_csv('eligibilty_test.csv', index=False)

# %%
usecase1_test = df1.head(500)

# %%
usecase1_test.to_csv('usecase1_test.csv', index=False)

# %% [markdown]
# # Using the usecase1 test dataset

# %%
usecase1_test_v2 = pd.read_csv('usecase1_test.csv')

# %%
usecase1_test_v2.drop(columns='Acronym', inplace=True)

# %%
usecase1_test_v2.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT03302091  A Study in People With Normal Kidney Function ...
# 1  NCT01948791  16w Interventional Study on Titration and Dose...
# 2  NCT04621591           Case Series With Saneso 360° Gastroscope
# 3  NCT03130491  European Study Evaluating the EMBLOK Embolic P...
# 4  NCT01580891  Evaluate the Clinical Equivalence of Two Nafti...
#
#                                       Study URL Study Status  \
# 0  https://clinicaltrials.gov/study/NCT03302091    COMPLETED
# 1  https://clinicaltrials.gov/study/NCT01948791    COMPLETED
# 2  https://clinicaltrials.gov/study/NCT04621591    COMPLETED
# 3  https://clinicaltrials.gov/study/NCT03130491    COMPLETED
# 4  https://clinicaltrials.gov/study/NCT01580891    COMPLETED
#
#                                        Brief Summary Study Results  \
# 0  The primary objective of the current study is ...           YES
# 1  To investigate the efficacy of Exelon capsule ...           YES
# 2  To confirm the procedural performance of the S...            NO
# 3  The primary objective is to evaluate the perfo...            NO
# 4  The objective of this study is to evaluate the...            NO
#
#                     Conditions  \
# 0  Renal Insufficiency|Healthy
# 1          Alzheimer's Disease
# 2                EGD Procedure
# 3         Aortic Valve Disease
# 4                  Tinea Pedis
#
#                                        Interventions  \
# 0                                   DRUG: BI 1467335
# 1                                       DRUG: ENA713
# 2                    DEVICE: Saneso 360° gastroscope
# 3  PROCEDURE: Transcatheter Aortic Valve Replacem...
# 4  DRUG: Naftifine HCl Cream 1%|DRUG: Naftin® (Na...
#
#                             Primary Outcome Measures  \
# 0  Area Under the Concentration-time Curve of BI ...
# 1  Mean Change From Baseline in the Alzheimer's D...
# 2  Successful EGD, Procedure success is assessed ...
# 3  Performance Endpoint, successful insertion, pl...
# 4  Therapeutic Cure, Patients with both mycologic...
#
#                           Secondary Outcome Measures  ...  \
# 0  Area Under the Concentration-time Curve of BI ...  ...
# 1  Change From Baseline in the Alzheimer's Diseas...  ...
# 2  Endoscopist qualitative rating of the Saneso 3...  ...
# 3  Safety Endpoint (Rate of MACCE), Rate of MACCE...  ...
# 4                                                NaN  ...
#
#                                         Study Design  \
# 0  Allocation: NON_RANDOMIZED|Intervention Model:...
# 1  Allocation: NA|Intervention Model: SINGLE_GROU...
# 2  Allocation: NA|Intervention Model: SINGLE_GROU...
# 3  Allocation: NA|Intervention Model: SINGLE_GROU...
# 4  Allocation: RANDOMIZED|Intervention Model: PAR...
#
#                   Other IDs  Start Date Primary Completion Date  \
# 0  1386-0002|2017-002180-18  2017-10-17              2018-08-16
# 1              CENA713BCN05     2014-08                 2015-09
# 2               SAN360UGICL  2020-08-01              2020-08-30
# 3               CLP002-2016  2017-03-08              2021-11-01
# 4               NTFC 1105.0     2012-05                 2013-03
#
#   Completion Date First Posted  Results First Posted Last Update Posted  \
# 0      2018-08-16   2017-10-04            2021-06-04         2021-06-04
# 1         2015-09   2013-09-24            2017-02-13         2017-02-13
# 2      2020-09-09   2020-11-09                   NaN         2020-11-10
# 3      2022-01-28   2017-04-26                   NaN         2024-03-05
# 4         2013-07   2012-04-19                   NaN         2014-05-06
#
#                                            Locations  \
# 0  CRS Clinical Research Services Kiel GmbH, Kiel...
# 1  Novartis Investigative Site, Beijing, 100053, ...
# 2  Valley Endoscopy Center, Saint Clairsville, Oh...
# 3  Hospital San Donato, Milan, Milano, 20097, Ita...
# 4                                                NaN
#
#                                      Study Documents
# 0  Study Protocol, https://cdn.clinicaltrials.gov...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # Checking the number of null values

# %%
null_values = usecase1_test_v2.isnull().sum()
print(null_values)
# Out:
# NCT Number                      0
# Study Title                     0
# Study URL                       0
# Study Status                    0
# Brief Summary                   0
# Study Results                   0
# Conditions                      0
# Interventions                  29
# Primary Outcome Measures       10
# Secondary Outcome Measures     97
# Other Outcome Measures        462
# Sponsor                         0
# Collaborators                 410
# Sex                             1
# Age                             0
# Phases                        158
# Enrollment                      7
# Funder Type                     0
# Study Type                      0
# Study Design                    3
# Other IDs                       0
# Start Date                      6
# Primary Completion Date        23
# Completion Date                24
# First Posted                    0
# Results First Posted          349
# Last Update Posted              0
# Locations                      69
# Study Documents               448
# dtype: int64

# %%
usecase1_test_v2.head(1)
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT03302091  A Study in People With Normal Kidney Function ...
#
#                                       Study URL Study Status  \
# 0  https://clinicaltrials.gov/study/NCT03302091    COMPLETED
#
#                                        Brief Summary Study Results  \
# 0  The primary objective of the current study is ...           YES
#
#                     Conditions     Interventions  \
# 0  Renal Insufficiency|Healthy  DRUG: BI 1467335
#
#                             Primary Outcome Measures  \
# 0  Area Under the Concentration-time Curve of BI ...
#
#                           Secondary Outcome Measures  ...  \
# 0  Area Under the Concentration-time Curve of BI ...  ...
#
#                                         Study Design  \
# 0  Allocation: NON_RANDOMIZED|Intervention Model:...
#
#                   Other IDs  Start Date Primary Completion Date  \
# 0  1386-0002|2017-002180-18  2017-10-17              2018-08-16
#
#   Completion Date First Posted  Results First Posted Last Update Posted  \
# 0      2018-08-16   2017-10-04            2021-06-04         2021-06-04
#
#                                            Locations  \
# 0  CRS Clinical Research Services Kiel GmbH, Kiel...
#
#                                      Study Documents
# 0  Study Protocol, https://cdn.clinicaltrials.gov...
#
# [1 rows x 29 columns]

# %% [markdown]
# # Fixing the datatype of date columns

# %%
from datetime import datetime

date_columns = [
    'Start Date', 
    'Primary Completion Date', 
    'Completion Date', 
    'First Posted', 
    'Results First Posted', 
    'Last Update Posted'
]
usecase1_test_v2[date_columns] = usecase1_test_v2[date_columns].apply(
    pd.to_datetime, format='%Y-%m-%d', errors='coerce'
)

# %%
print(usecase1_test_v2.head(100)['First Posted'])
# Out:
# 0    2017-10-04
# 1    2013-09-24
# 2    2020-11-09
# 3    2017-04-26
# 4    2012-04-19
#         ...
# 95   2008-08-26
# 96   2008-03-28
# 97   2017-05-25
# 98   2020-08-28
# 99   2013-10-10
# Name: First Posted, Length: 100, dtype: datetime64[ns]

# %%
for column in date_columns:
    print(f"{column}: {usecase1_test_v2[column].dtype}")
# Out:
# Start Date: datetime64[ns]
# Primary Completion Date: datetime64[ns]
# Completion Date: datetime64[ns]
# First Posted: datetime64[ns]
# Results First Posted: datetime64[ns]
# Last Update Posted: datetime64[ns]

# %%
usecase1_test_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NCT Number                  500 non-null    object
#  1   Study Title                 500 non-null    object
#  2   Study URL                   500 non-null    object
#  3   Study Status                500 non-null    object
#  4   Brief Summary               500 non-null    object
#  5   Study Results               500 non-null    object
#  6   Conditions                  500 non-null    object
#  7   Interventions               471 non-null    object
#  8   Primary Outcome Measures    490 non-null    object
#  9   Secondary Outcome Measures  403 non-null    object
#  10  Other Outcome Measures      38 non-null     object
#  11  Sponsor                     500 non-null    object
#  12  Collaborators               90 non-null     object
#  13  Sex                         499 non-null    object
#  14  Age                         500 non-null    object
#  15  Phases                      342 non-null    object
#  16  Enrollment                  493 non-null    float64
#  17  Funder Type                 500 non-null    object
#  18  Study Type                  500 non-null    object
#  19  Study Design                497 non-null    object
#  20  Other IDs                   500 non-null    object
#  21  Start Date                  264 non-null    datetime64[ns]
#  22  Primary Completion Date     245 non-null    datetime64[ns]
#  23  Completion Date             242 non-null    datetime64[ns]
#  24  First Posted                500 non-null    datetime64[ns]
#  25  Results First Posted        151 non-null    datetime64[ns]
#  26  Last Update Posted          500 non-null    datetime64[ns]
#  27  Locations                   431 non-null    object
#  28  Study Documents             52 non-null     object
# dtypes: datetime64[ns](6), float64(1), object(22)
# memory usage: 113.4+ KB

# %%
import seaborn as sns
import os

import matplotlib.pyplot as plt

# Calculate the percentage of missing values in each column
missing_percentage = usecase1_test.isnull().mean() * 100
print(missing_percentage)

# Create a heatmap to visualize the patterns of missing values
plt.figure(figsize=(12, 8))
sns.heatmap(usecase1_test.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.xlabel('Columns')
plt.ylabel('Rows')

# Create directory if it doesn't exist
if not os.path.exists('data cleaning images'):
    os.makedirs('data cleaning images')

# Save the heatmap
plt.savefig('data cleaning images/missing_values_heatmap.png')
plt.show()

# Identify columns with high missingness rates
high_missingness = missing_percentage[missing_percentage > 20]
print("Columns with more than 20% missing values:")
print(high_missingness)
# Out:
# NCT Number                     0.0
# Study Title                    0.0
# Study URL                      0.0
# Study Status                   0.0
# Brief Summary                  0.0
# Study Results                  0.0
# Conditions                     0.0
# Interventions                  5.8
# Primary Outcome Measures       2.0
# Secondary Outcome Measures    19.4
# Other Outcome Measures        92.4
# Sponsor                        0.0
# Collaborators                 82.0
# Sex                            0.2
# Age                            0.0
# Phases                        31.6
# Enrollment                     1.4
# Funder Type                    0.0
# Study Type                     0.0
# Study Design                   0.6
# Other IDs                      0.0
# Start Date                    47.2
# Primary Completion Date       51.0
# Completion Date               51.6
# First Posted                   0.0
# Results First Posted          69.8
# Last Update Posted             0.0
# Locations                     13.8
# Study Documents               89.6
# dtype: float64
# Columns with more than 20% missing values:
# Other Outcome Measures     92.4
# Collaborators              82.0
# Phases                     31.6
# Start Date                 47.2
# Primary Completion Date    51.0
# Completion Date            51.6
# Results First Posted       69.8
# Study Documents            89.6
# dtype: float64

# %% [markdown]
# # Handling missing values from now on
